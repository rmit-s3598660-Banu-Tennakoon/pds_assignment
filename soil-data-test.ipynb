# %%
import pandas as pd
import csv
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
column_names = ("Elevation","Aspect","Slope","Horizontal_Distance_To_Hydrology","Vertical_Distance_To_Hydrology","Horizontal_Distance_To_Roadways","Hillshade_9am","Hillshade_Noon","Hillshade_3pm","Horizontal_Distance_To_Fire_Points","Wilderness_Area_01","Wilderness_Area_02","Wilderness_Area_03","Wilderness_Area_04","Soil_Type_01","Soil_Type_02","Soil_Type_03","Soil_Type_04","Soil_Type_05","Soil_Type_06","Soil_Type_07","Soil_Type_08","Soil_Type_09","Soil_Type_10","Soil_Type_11","Soil_Type_12","Soil_Type_13","Soil_Type_14","Soil_Type_15","Soil_Type_16","Soil_Type_17","Soil_Type_18","Soil_Type_19","Soil_Type_20","Soil_Type_21","Soil_Type_22","Soil_Type_23","Soil_Type_24","Soil_Type_25","Soil_Type_26","Soil_Type_27","Soil_Type_28","Soil_Type_29","Soil_Type_30","Soil_Type_31","Soil_Type_32","Soil_Type_33","Soil_Type_34","Soil_Type_35","Soil_Type_36","Soil_Type_37","Soil_Type_38","Soil_Type_39","Soil_Type_40","Cover_Type"
)

# %%
soil = pd.read_table("covtype.data", sep=",", names=column_names)

# %%
soil.shape
# Out:
# (581012, 55)

# %%
soil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 55 columns):
# Elevation                             581012 non-null int64
# Aspect                                581012 non-null int64
# Slope                                 581012 non-null int64
# Horizontal_Distance_To_Hydrology      581012 non-null int64
# Vertical_Distance_To_Hydrology        581012 non-null int64
# Horizontal_Distance_To_Roadways       581012 non-null int64
# Hillshade_9am                         581012 non-null int64
# Hillshade_Noon                        581012 non-null int64
# Hillshade_3pm                         581012 non-null int64
# Horizontal_Distance_To_Fire_Points    581012 non-null int64
# Wilderness_Area_01                    581012 non-null int64
# Wilderness_Area_02                    581012 non-null int64
# Wilderness_Area_03                    581012 non-null int64
# Wilderness_Area_04                    581012 non-null int64
# ...

# %%
## DATA PREPARATION
## Should all soil types be changed to categorical too ??

# %%
soil['Wilderness_Area_01'] = soil['Wilderness_Area_01'].astype('category')
soil['Wilderness_Area_02'] = soil['Wilderness_Area_02'].astype('category')
soil['Wilderness_Area_03'] = soil['Wilderness_Area_03'].astype('category')
soil['Wilderness_Area_04'] = soil['Wilderness_Area_04'].astype('category')
soil['Soil_Type_01'] = soil['Soil_Type_01'].astype('category')
soil['Soil_Type_02'] = soil['Soil_Type_02'].astype('category')
soil['Soil_Type_03'] = soil['Soil_Type_03'].astype('category')
soil['Soil_Type_04'] = soil['Soil_Type_04'].astype('category')
soil['Soil_Type_05'] = soil['Soil_Type_05'].astype('category')
soil['Soil_Type_06'] = soil['Soil_Type_06'].astype('category')
soil['Soil_Type_07'] = soil['Soil_Type_07'].astype('category')
soil['Soil_Type_08'] = soil['Soil_Type_08'].astype('category')
soil['Soil_Type_09'] = soil['Soil_Type_09'].astype('category')
soil['Soil_Type_10'] = soil['Soil_Type_10'].astype('category')
soil['Soil_Type_11'] = soil['Soil_Type_11'].astype('category')
soil['Soil_Type_12'] = soil['Soil_Type_12'].astype('category')
soil['Soil_Type_13'] = soil['Soil_Type_13'].astype('category')
soil['Soil_Type_14'] = soil['Soil_Type_14'].astype('category')
soil['Soil_Type_15'] = soil['Soil_Type_15'].astype('category')
soil['Soil_Type_16'] = soil['Soil_Type_16'].astype('category')
soil['Soil_Type_17'] = soil['Soil_Type_17'].astype('category')
soil['Soil_Type_18'] = soil['Soil_Type_18'].astype('category')
soil['Soil_Type_19'] = soil['Soil_Type_19'].astype('category')
soil['Soil_Type_20'] = soil['Soil_Type_20'].astype('category')
soil['Soil_Type_21'] = soil['Soil_Type_21'].astype('category')
soil['Soil_Type_22'] = soil['Soil_Type_22'].astype('category')
soil['Soil_Type_23'] = soil['Soil_Type_23'].astype('category')
soil['Soil_Type_24'] = soil['Soil_Type_24'].astype('category')
soil['Soil_Type_25'] = soil['Soil_Type_25'].astype('category')
soil['Soil_Type_26'] = soil['Soil_Type_26'].astype('category')
soil['Soil_Type_27'] = soil['Soil_Type_27'].astype('category')
soil['Soil_Type_28'] = soil['Soil_Type_28'].astype('category')
soil['Soil_Type_29'] = soil['Soil_Type_29'].astype('category')
soil['Soil_Type_30'] = soil['Soil_Type_30'].astype('category')
soil['Soil_Type_31'] = soil['Soil_Type_31'].astype('category')
soil['Soil_Type_32'] = soil['Soil_Type_32'].astype('category')
soil['Soil_Type_33'] = soil['Soil_Type_33'].astype('category')
soil['Soil_Type_34'] = soil['Soil_Type_34'].astype('category')
soil['Soil_Type_35'] = soil['Soil_Type_35'].astype('category')
soil['Soil_Type_36'] = soil['Soil_Type_36'].astype('category')
soil['Soil_Type_37'] = soil['Soil_Type_37'].astype('category')
soil['Soil_Type_38'] = soil['Soil_Type_38'].astype('category')
soil['Soil_Type_39'] = soil['Soil_Type_39'].astype('category')
soil['Soil_Type_40'] = soil['Soil_Type_40'].astype('category')
soil['Cover_Type'] = soil['Cover_Type'].astype('category')

# %%
soil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 55 columns):
# Elevation                             581012 non-null int64
# Aspect                                581012 non-null int64
# Slope                                 581012 non-null int64
# Horizontal_Distance_To_Hydrology      581012 non-null int64
# Vertical_Distance_To_Hydrology        581012 non-null int64
# Horizontal_Distance_To_Roadways       581012 non-null int64
# Hillshade_9am                         581012 non-null int64
# Hillshade_Noon                        581012 non-null int64
# Hillshade_3pm                         581012 non-null int64
# Horizontal_Distance_To_Fire_Points    581012 non-null int64
# Wilderness_Area_01                    581012 non-null category
# Wilderness_Area_02                    581012 non-null category
# Wilderness_Area_03                    581012 non-null category
# Wilderness_Area_04                    581012 non-null category
# ...

# %% [markdown]
# # PART 2 - DATA EXPLORATION

# %% [markdown]
# ### A - EXPLORE EACH COLUMN

# %% [markdown]
# #### USING APPROPRIATE DESCRIPTIVE STATISTICS

# %%
soil.describe()
# Out:
#            Elevation         Aspect          Slope  \
# count  581012.000000  581012.000000  581012.000000
# mean     2959.365301     155.656807      14.103704
# std       279.984734     111.913721       7.488242
# min      1859.000000       0.000000       0.000000
# 25%      2809.000000      58.000000       9.000000
# 50%      2996.000000     127.000000      13.000000
# 75%      3163.000000     260.000000      18.000000
# max      3858.000000     360.000000      66.000000
#
#        Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# count                     581012.000000                   581012.000000
# mean                         269.428217                       46.418855
# std                          212.549356                       58.295232
# min                            0.000000                     -173.000000
# 25%                          108.000000                        7.000000
# ...

# %%
for col in soil.columns:
    if (soil[col].dtype.name == 'int64'):
        print soil[col].value_counts(), '\n'
# Out:
# 2968    1681
# 2962    1674
# 2991    1671
# 2972    1662
# 2975    1656
# 2978    1656
# 2988    1619
# 2955    1590
# 2952    1577
# 2965    1571
# 2985    1567
# 2998    1557
# 2982    1554
# 2959    1551
# 3008    1517
# 2995    1509
# 3001    1502
# 2942    1475
# 3004    1469
# 2932    1455
# 2945    1453
# 2949    1446
# 2939    1440
# 3014    1434
# 3011    1433
# 3034    1411
# 3031    1385
# 3021    1364
# 3027    1363
# 3018    1363
#         ...
# 3853       1
# 3797       1
# 3850       1
# 3798       1
# 3841       1
# 1884       1
# 3684       1
# 3813       1
# 3687       1
# 3835       1
# 3832       1
# 3826       1
# 3856       1
# 3793       1
# 3790       1
# 1859       1
# 1860       1
# 1861       1
# 1863       1
# 1866       1
# 1867       1
# 3779       1
# 1868       1
# 3676       1
# 1873       1
# 1874       1
# 3771       1
# 1881       1
# 3767       1
# 3768       1
# Name: Elevation, Length: 1978, dtype: int64
#
# 45     6308
# 0      4914
# ...

# %%
for col in soil.columns:
    if (soil[col].dtype.name == 'category'):
        print soil[col].value_counts(), '\n'
# Out:
# 0    320216
# 1    260796
# Name: Wilderness_Area_01, dtype: int64
#
# 0    551128
# 1     29884
# Name: Wilderness_Area_02, dtype: int64
#
# 0    327648
# 1    253364
# Name: Wilderness_Area_03, dtype: int64
#
# 0    544044
# 1     36968
# Name: Wilderness_Area_04, dtype: int64
#
# 0    577981
# 1      3031
# Name: Soil_Type_01, dtype: int64
#
# 0    573487
# 1      7525
# Name: Soil_Type_02, dtype: int64
#
# 0    576189
# 1      4823
# Name: Soil_Type_03, dtype: int64
#
# 0    568616
# 1     12396
# Name: Soil_Type_04, dtype: int64
#
# 0    579415
# 1      1597
# Name: Soil_Type_05, dtype: int64
#
# 0    574437
# 1      6575
# Name: Soil_Type_06, dtype: int64
#
# 0    580907
# 1       105
# Name: Soil_Type_07, dtype: int64
#
# 0    580833
# 1       179
# Name: Soil_Type_08, dtype: int64
#
# 0    579865
# 1      1147
# Name: Soil_Type_09, dtype: int64
#
# 0    548378
# 1     32634
# Name: Soil_Type_10, dtype: int64
#
# 0    568602
# 1     12410
# Name: Soil_Type_11, dtype: int64
#
# ...

# %%
for col in soil.columns:
    if (soil[col].dtype.name == 'category'):
        print soil[col].value_counts(normalize=True), '\n'
# Out:
# 0    0.551135
# 1    0.448865
# Name: Wilderness_Area_01, dtype: float64
#
# 0    0.948566
# 1    0.051434
# Name: Wilderness_Area_02, dtype: float64
#
# 0    0.563926
# 1    0.436074
# Name: Wilderness_Area_03, dtype: float64
#
# 0    0.936373
# 1    0.063627
# Name: Wilderness_Area_04, dtype: float64
#
# 0    0.994783
# 1    0.005217
# Name: Soil_Type_01, dtype: float64
#
# 0    0.987048
# 1    0.012952
# Name: Soil_Type_02, dtype: float64
#
# 0    0.991699
# 1    0.008301
# Name: Soil_Type_03, dtype: float64
#
# 0    0.978665
# 1    0.021335
# Name: Soil_Type_04, dtype: float64
#
# 0    0.997251
# 1    0.002749
# Name: Soil_Type_05, dtype: float64
#
# 0    0.988684
# 1    0.011316
# Name: Soil_Type_06, dtype: float64
#
# 0    0.999819
# 1    0.000181
# Name: Soil_Type_07, dtype: float64
#
# 0    0.999692
# 1    0.000308
# Name: Soil_Type_08, dtype: float64
#
# 0    0.998026
# 1    0.001974
# Name: Soil_Type_09, dtype: float64
#
# 0    0.943832
# 1    0.056168
# ...

# %%
## BOXPLOT FOR NUMERICAL DATA EXPLORATION

i = 0
#title = ("Analysis of Elevation data", "Aspect data", "Slope data", "Horizontal Distance", "Vertical Distance", "The number of emergency visits of the patient in the year preceding the encounter", "The number of inpatient visits of the patient in the year preceding the encounter", "The number of diagnoses entered to the system")
#yaxis= ("Time (in days)", "Number of procedures", "Number of non-lab procedures", "Number of medications", "Number of visits", "Number of visits", "Number of visits", "Number of diagnoses")
#xaxis= ("The number of visits of this duration", "Frequency of this many procedures", "Frequency of this many procedures", "Frequency of this many medications", "The number of patients that had this number of visits", "The number of patients that had this number of visits", "The number of patients that had this number of visits", "The number of patients that had this number of diagnoses")

for col in soil.columns:
    if (soil[col].dtype.name == 'int64'):
        #print diabetes[col].name + '\n'
        plt.figure(col)
        soil.boxplot(column=col)
        #plt.title(title[i])
        #plt.ylabel(yaxis[i])
        i = i + 1       
        #plt.xlabel(xaxis[i])

# %%
## PIECHART FOR CATEGORICAL DATA EXPLORATION
i = 0 

for col in soil.columns:
    if (soil[col].dtype.name  == 'category'):
        plt.figure(col)
        soil[col].value_counts().plot(kind='pie',autopct='%.2f')
        plt.axis('equal')
        #plt.pie(diabetes[col].value_counts)
        #plt.xlabel(xlabels[i])
        #plt.ylabel("Frequency count")
        #i = i + 1
# Out:
# /Users/ellenitoumpas/anaconda2/lib/python2.7/site-packages/matplotlib/pyplot.py:528: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)

# %% [markdown]
# ## B - EXPLORE RELATIONSHIPS BETWEEN ALL ATTRIBUTES

# %%
# MEAN OF ALL DATA

# %%
for col in soil.columns:
    if (soil[col].dtype.name  == 'int64'):
        print soil[col].groupby(soil["Cover_Type"]).mean(), '\n'
# Out:
# Cover_Type
# 1    3128.644888
# 2    2920.936061
# 3    2394.509845
# 4    2223.939934
# 5    2787.417571
# 6    2419.181897
# 7    3361.928669
# Name: Elevation, dtype: float64
#
# Cover_Type
# 1    156.138227
# 2    152.060515
# 3    176.372490
# 4    137.139425
# 5    139.283051
# 6    180.539068
# 7    153.236226
# Name: Aspect, dtype: float64
#
# Cover_Type
# 1    13.127110
# 2    13.550499
# 3    20.770208
# 4    18.528941
# 5    16.641315
# 6    19.048886
# 7    14.255924
# Name: Slope, dtype: float64
#
# Cover_Type
# 1    270.555245
# 2    279.916442
# 3    210.276473
# 4    106.934838
# 5    212.354893
# 6    159.853458
# 7    356.994686
# Name: Horizontal_Distance_To_Hydrology, dtype: float64
#
# Cover_Type
# 1    42.156939
# 2    45.884219
# 3    62.446915
# 4    41.186749
# 5    50.610344
# 6    45.437439
# 7    69.474305
# Name: Vertical_Distance_To_Hydrology, dtype: float64
#
# Cover_Type
# 1    2614.834517
# 2    2429.530799
# 3     943.940734
# 4     914.199490
# ...

# %%
for col in soil.columns:
    if (soil[col].dtype.name  == 'int64'):
        plt.figure(col)
        soil.boxplot(column=col, by="Cover_Type")

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(soil,alpha=0.2,figsize=(20,20),diagonal='hist')
plt.show()

# %%
# grouped = soil.groupby(['A1Cresult']).diag_2.value_counts(normalize=True)
# grouped.unstack().plot(kind='bar', subplots=True, layout=(4,3), figsize=(20,20))

# %%
soil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 55 columns):
# Elevation                             581012 non-null int64
# Aspect                                581012 non-null int64
# Slope                                 581012 non-null int64
# Horizontal_Distance_To_Hydrology      581012 non-null int64
# Vertical_Distance_To_Hydrology        581012 non-null int64
# Horizontal_Distance_To_Roadways       581012 non-null int64
# Hillshade_9am                         581012 non-null int64
# Hillshade_Noon                        581012 non-null int64
# Hillshade_3pm                         581012 non-null int64
# Horizontal_Distance_To_Fire_Points    581012 non-null int64
# Wilderness_Area_01                    581012 non-null category
# Wilderness_Area_02                    581012 non-null category
# Wilderness_Area_03                    581012 non-null category
# Wilderness_Area_04                    581012 non-null category
# ...

# %%
## DATA MODELLING

# %%
import pandas as pd
from scipy import stats
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import preprocessing
from mpl_toolkits.mplot3d import Axes3D

# %%
df_tr = soil

# %%
clmns = ['Elevation','Aspect','Slope','Horizontal_Distance_To_Hydrology','Vertical_Distance_To_Hydrology','Horizontal_Distance_To_Roadways','Hillshade_9am', 'Hillshade_Noon','Hillshade_3pm','Horizontal_Distance_To_Fire_Points']
df_tr_std = stats.zscore(df_tr[clmns])

# %%
#Cluster the data
kmeans = KMeans(n_clusters=7, random_state=5).fit(df_tr_std)
kmeans
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=7, n_init=10, n_jobs=1, precompute_distances='auto',
#     random_state=5, tol=0.0001, verbose=0)

# %%
labels = kmeans.labels_

# %%
#Glue back to original data
df_tr['clusters'] = labels

# %%
#Add the column into our list
clmns.extend(['clusters'])

#Lets analyze the clusters
#Find out how many instances in cluster
print (df_tr[clmns].groupby(['clusters']).mean())
# Out:
#             Elevation      Aspect      Slope  \
# clusters
# 0         2931.928117  134.407483   9.841233
# 1         3053.919044  283.810644  11.649301
# 2         3176.873446  150.184830  14.245902
# 3         2863.300253   85.091474  11.290007
# 4         2695.880518  300.970787  24.655837
# 5         3128.441931   82.276744  10.684040
# 6         2803.017544   65.418111  24.201791
#
#           Horizontal_Distance_To_Hydrology  Vertical_Distance_To_Hydrology  \
# clusters
# 0                               272.141652                       31.317159
# 1                               237.977324                       29.792269
# 2                               671.061907                      155.663925
# 3                               200.046266                       21.741874
# 4                               224.161626                       71.288536
# 5                               226.906016                       25.502519
# ...

# %%
#Scatter plot
sns.lmplot('Horizontal_Distance_To_Roadways', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Aspect', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Slope', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Horizontal_Distance_To_Hydrology', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Vertical_Distance_To_Hydrology', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Horizontal_Distance_To_Roadways', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Hillshade_9am', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Hillshade_Noon', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Hillshade_3pm', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
#Scatter plot
sns.lmplot('Horizontal_Distance_To_Fire_Points', 'Elevation', 
           data=df_tr, 
           fit_reg=False, 
           hue="clusters",  
           scatter_kws={"marker": "D", 
                        "s": 25})
#plt.title('Time in Hospital vs Number of Diagnoses')
#plt.xlabel('Time in Hospital')
#plt.ylabel('Number of Diagnoses')

# %%
soil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 581012 entries, 0 to 581011
# Data columns (total 56 columns):
# Elevation                             581012 non-null int64
# Aspect                                581012 non-null int64
# Slope                                 581012 non-null int64
# Horizontal_Distance_To_Hydrology      581012 non-null int64
# Vertical_Distance_To_Hydrology        581012 non-null int64
# Horizontal_Distance_To_Roadways       581012 non-null int64
# Hillshade_9am                         581012 non-null int64
# Hillshade_Noon                        581012 non-null int64
# Hillshade_3pm                         581012 non-null int64
# Horizontal_Distance_To_Fire_Points    581012 non-null int64
# Wilderness_Area_01                    581012 non-null category
# Wilderness_Area_02                    581012 non-null category
# Wilderness_Area_03                    581012 non-null category
# Wilderness_Area_04                    581012 non-null category
# ...
